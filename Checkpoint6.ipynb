# %%
import pandas as pd 
df = pd.read_csv('C:\\Users\\Pc\\Desktop\\Gomycode\\iris.csv', sep=',')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
import random

def loadDataset(iris, split, trainingSet=[] , testSet=[]):

with open(iris, 'r') as csvfile:

  lines = csv.reader(iris)

  df = list(lines)

  for x in range(len(df)-1):

    for y in range(4):

      dataset[x][y] = float(dataset[x][y])

    if random.random() < split:

      complete code

    else:

      complete code
# Out:
#   File "<ipython-input-4-9d755ecf6af6>", line 5
#     with open(iris, 'r') as csvfile:
#     ^
# IndentationError: expected an indented block

# %%
import math

def euclideanDistance(instance1, instance2, length):
    a=0
    for i in range (len(instance1)):
        a=a+(intsance1[i]-instance2[i])^2
    distance=sqrt(a)

    print ('Distance: ' + repr(distance))

# %%
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-6-13ecc19be493> in <module>
#       2
#       3 data2 = [4, 4, 4, 'b']
# ----> 4 euclideanDistance(data1, data2, 3)
#
# <ipython-input-4-031779e4ec0d> in euclideanDistance(instance1, instance2, length)
#       8     data2 = [4, 4, 4, 'b']
#       9
# ---> 10     distance = euclideanDistance(data1, data2, 3)
#      11
#      12     print ('Distance: ' + repr(distance))
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-4-031779e4ec0d> in euclideanDistance(instance1, instance2, length)
#       8     data2 = [4, 4, 4, 'b']
#       9
# ---> 10     distance = euclideanDistance(data1, data2, 3)
#      11
#      12     print ('Distance: ' + repr(distance))
#
# RecursionError: maximum recursion depth exceeded

# %%
import operator

def getNeighbors(trainingSet, testInstance, k):

    distances = []

    length = len(testInstance)-1

    for x in range(len(trainingSet)):

        dist = euclideanDistance(testInstance, trainingSet[x], length)

        distances.append((trainingSet[x], dist))

        distances.sort(key=operator.itemgetter(1))

    neighbors = []

    for x in range(k):

        neighbors.append(distances[x][0])

    return neighbors

# %%
trainSet = [[2, 2, 2, 'a'], [4, 4, 4, 'b']]

testInstance = [5, 5, 5]

k = 1

neighbors = getNeighbors(trainSet, testInstance, 1)

print(neighbors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-607e89ef00cd> in <module>
#       5 k = 1
#       6
# ----> 7 neighbors = getNeighbors(trainSet, testInstance, 1)
#       8
#       9 print(neighbors)
#
# <ipython-input-11-26503ce6e5fb> in getNeighbors(trainingSet, testInstance, k)
#       9     for x in range(len(trainingSet)):
#      10
# ---> 11         dist = euclideanDistance(testInstance, trainingSet[x], length)
#      12
#      13         distances.append((trainingSet[x], dist))
#
# <ipython-input-9-5f927756b598> in euclideanDistance(instance1, instance2, length)
#       4     a=0
#       5     for i in range (len(instance1)):
# ----> 6         a=a+(intsance1[i]-instance2[i])^2
#       7     distance=sqrt(a)
#       8
#
# NameError: name 'intsance1' is not defined
